# %% [markdown]
# <a href="https://colab.research.google.com/github/rhyan05/Extra-o-de-Dados---Python-IBGE/blob/main/IBGE_Dados_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from time import sleep

def capta_dados_IBGE():
    url = "https://servicodados.ibge.gov.br/api/v1/localidades/estados/SP/municipios"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Falha ao acessar a API - Código de status -> Capt: {response.status_code}")

def rankeando(municipal_id):
    url = f"https://servicodados.ibge.gov.br/api/v2/censos/nomes/ranking?localidade={municipal_id}"
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception(f"Falha ao acessar a API - Código de status -> Rank: {response.status_code}")
    return response.json()

def process_municipalities():
    municipios = capta_dados_IBGE()
    gabriel_results = {}
    gabriel_top1_count = 0  # contador de municípios onde Gabriel é o 1º nome

    for mun in municipios:
        mun_id = mun["id"]
        mun_nome = mun["nome"]

        print(f"Processando: {mun_nome}")
        sleep(0.5)

        try:
            ranking_data = rankeando(mun_id)
        except Exception as e:
            print(f"Erro em {mun_nome}: {e}")
            continue

        if ranking_data and len(ranking_data) > 0:
            ranking = ranking_data[0].get('res', [])
            for idx, item in enumerate(ranking[:10]):
                nome = item['nome'].upper()
                if nome == 'GABRIEL':
                    gabriel_results[mun_nome] = item['frequencia']
                    if idx == 0:  # se for o 1º da lista (índice 0)
                        gabriel_top1_count += 1
                    break

    return gabriel_results, gabriel_top1_count

def save_to_json(data, filename='gabriel_top10.json'):
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

def main():
    try:
        results, top1_count = process_municipalities()
        sorted_results = dict(sorted(results.items(), key=lambda item: item[1], reverse=True))
        save_to_json(sorted_results)

        print("\nProcesso concluído! Resultados salvos em gabriel_top10.json")
        print(f"Total de municípios com Gabriel no top 10: {len(sorted_results)}")
        print(f"Gabriel foi o nome MAIS popular (1º lugar) em {top1_count} municípios.")

    except Exception as e:
        print(f"Ocorreu um erro: {e}")

main()
# Out:
# Processando: Adamantina
# Processando: Adolfo
# Processando: Aguaí
# Processando: Águas da Prata
# Processando: Águas de Lindóia
# Processando: Águas de Santa Bárbara
# Processando: Águas de São Pedro
# Processando: Agudos
# Processando: Alambari
# Processando: Alfredo Marcondes
# Processando: Altair
# Processando: Altinópolis
# Processando: Alto Alegre
# Processando: Alumínio
# Processando: Álvares Florence
# Processando: Álvares Machado
# Processando: Álvaro de Carvalho
# Processando: Alvinlândia
# Processando: Americana
# Processando: Américo Brasiliense
# Processando: Américo de Campos
# Processando: Amparo
# Processando: Analândia
# Processando: Andradina
# Processando: Angatuba
# Processando: Anhembi
# Processando: Anhumas
# Processando: Aparecida
# Processando: Aparecida d'Oeste
# Processando: Apiaí
# Processando: Araçariguama
# Processando: Araçatuba
# Processando: Araçoiaba da Serra
# Processando: Aramina
# Processando: Arandu
# Processando: Arapeí
# Processando: Araraquara
# Processando: Araras
# Processando: Arco-Íris
# Processando: Arealva
# Processando: Areias
# Processando: Areiópolis
# Processando: Ariranha
# Processando: Artur Nogueira
# Processando: Arujá
# Processando: Aspásia
# Processando: Assis
# Processando: Atibaia
# Processando: Auriflama
# Processando: Avaí
# Processando: Avanhandava
# Processando: Avaré
# Processando: Bady Bassitt
# Processando: Balbinos
# Processando: Bálsamo
# Processando: Bananal
# Processando: Barão de Antonina
# Processando: Barbosa
# Processando: Bariri
# Processando: Barra Bonita
# Processando: Barra do Chapéu
# Processando: Barra do Turvo
# Processando: Barretos
# Processando: Barrinha
# Processando: Barueri
# Processando: Bastos
# Processando: Batatais
# Processando: Bauru
# Processando: Bebedouro
# Processando: Bento de Abreu
# Processando: Bernardino de Campos
# Processando: Bertioga
# Processando: Bilac
# Processando: Birigui
# Processando: Biritiba Mirim
# Processando: Boa Esperança do Sul
# Processando: Bocaina
# Processando: Bofete
# Processando: Boituva
# Processando: Bom Jesus dos Perdões
# Processando: Bom Sucesso de Itararé
# Processando: Borá
# Processando: Boracéia
# Processando: Borborema
# Processando: Borebi
# Processando: Botucatu
# Processando: Bragança Paulista
# Processando: Braúna
# Processando: Brejo Alegre
# Processando: Brodowski
# Processando: Brotas
# Processando: Buri
# Processando: Buritama
# Processando: Buritizal
# Processando: Cabrália Paulista
# Processando: Cabreúva
# Processando: Caçapava
# Processando: Cachoeira Paulista
# Processando: Caconde
# Processando: Cafelândia
# Processando: Caiabu
# Processando: Caieiras
# Processando: Caiuá
# Processando: Cajamar
# Processando: Cajati
# Processando: Cajobi
# Processando: Cajuru
# Processando: Campina do Monte Alegre
# Processando: Campinas
# Processando: Campo Limpo Paulista
# Processando: Campos do Jordão
# Processando: Campos Novos Paulista
# Processando: Cananéia
# Processando: Canas
# Processando: Cândido Mota
# Processando: Cândido Rodrigues
# Processando: Canitar
# Processando: Capão Bonito
# Processando: Capela do Alto
# Processando: Capivari
# Processando: Caraguatatuba
# Processando: Carapicuíba
# Processando: Cardoso
# Processando: Casa Branca
# Processando: Cássia dos Coqueiros
# Processando: Castilho
# Processando: Catanduva
# Processando: Catiguá
# Processando: Cedral
# Processando: Cerqueira César
# Processando: Cerquilho
# Processando: Cesário Lange
# Processando: Charqueada
# Processando: Clementina
# Processando: Colina
# Processando: Colômbia
# Processando: Conchal
# Processando: Conchas
# Processando: Cordeirópolis
# Processando: Coroados
# Processando: Coronel Macedo
# Processando: Corumbataí
# Processando: Cosmópolis
# Processando: Cosmorama
# Processando: Cotia
# Processando: Cravinhos
# Processando: Cristais Paulista
# Processando: Cruzália
# Processando: Cruzeiro
# Processando: Cubatão
# Processando: Cunha
# Processando: Descalvado
# Processando: Diadema
# Processando: Dirce Reis
# Processando: Divinolândia
# Processando: Dobrada
# Processando: Dois Córregos
# Processando: Dolcinópolis
# Processando: Dourado
# Processando: Dracena
# Processando: Duartina
# Processando: Dumont
# Processando: Echaporã
# Processando: Eldorado
# Processando: Elias Fausto
# Processando: Elisiário
# Processando: Embaúba
# Processando: Embu das Artes
# Processando: Embu-Guaçu
# Processando: Emilianópolis
# Processando: Engenheiro Coelho
# Processando: Espírito Santo do Pinhal
# Processando: Espírito Santo do Turvo
# Processando: Estrela d'Oeste
# Processando: Estrela do Norte
# Processando: Euclides da Cunha Paulista
# Processando: Fartura
# Processando: Fernandópolis
# Processando: Fernando Prestes
# Processando: Fernão
# Processando: Ferraz de Vasconcelos
# Processando: Flora Rica
# Processando: Floreal
# Processando: Flórida Paulista
# Processando: Florínea
# Processando: Franca
# Processando: Francisco Morato
# Processando: Franco da Rocha
# Processando: Gabriel Monteiro
# Processando: Gália
# Processando: Garça
# Processando: Gastão Vidigal
# Processando: Gavião Peixoto
# Processando: General Salgado
# Processando: Getulina
# Processando: Glicério
# Processando: Guaiçara
# Processando: Guaimbê
# Processando: Guaíra
# Processando: Guapiaçu
# Processando: Guapiara
# Processando: Guará
# Processando: Guaraçaí
# Processando: Guaraci
# Processando: Guarani d'Oeste
# Processando: Guarantã
# Processando: Guararapes
# Processando: Guararema
# Processando: Guaratinguetá
# Processando: Guareí
# Processando: Guariba
# Processando: Guarujá
# Processando: Guarulhos
# Processando: Guatapará
# Processando: Guzolândia
# Processando: Herculândia
# Processando: Holambra
# Processando: Hortolândia
# Processando: Iacanga
# Processando: Iacri
# Processando: Iaras
# Processando: Ibaté
# Processando: Ibirá
# Processando: Ibirarema
# Processando: Ibitinga
# Processando: Ibiúna
# Processando: Icém
# Processando: Iepê
# Processando: Igaraçu do Tietê
# Processando: Igarapava
# Processando: Igaratá
# Processando: Iguape
# Processando: Ilhabela
# Processando: Ilha Comprida
# Processando: Ilha Solteira
# Processando: Indaiatuba
# Processando: Indiana
# Processando: Indiaporã
# Processando: Inúbia Paulista
# Processando: Ipaussu
# Processando: Iperó
# Processando: Ipeúna
# Processando: Ipiguá
# Processando: Iporanga
# Processando: Ipuã
# Processando: Iracemápolis
# Processando: Irapuã
# Processando: Irapuru
# Processando: Itaberá
# Processando: Itaí
# Processando: Itajobi
# Processando: Itaju
# Processando: Itanhaém
# Processando: Itaoca
# Processando: Itapecerica da Serra
# Processando: Itapetininga
# Processando: Itapeva
# Processando: Itapevi
# Processando: Itapira
# Processando: Itapirapuã Paulista
# Processando: Itápolis
# Processando: Itaporanga
# Processando: Itapuí
# Processando: Itapura
# Processando: Itaquaquecetuba
# Processando: Itararé
# Processando: Itariri
# Processando: Itatiba
# Processando: Itatinga
# Processando: Itirapina
# Processando: Itirapuã
# Processando: Itobi
# Processando: Itu
# Processando: Itupeva
# Processando: Ituverava
# Processando: Jaborandi
# Processando: Jaboticabal
# Processando: Jacareí
# Processando: Jaci
# Processando: Jacupiranga
# Processando: Jaguariúna
# Processando: Jales
# Processando: Jambeiro
# Processando: Jandira
# Processando: Jardinópolis
# Processando: Jarinu
# Processando: Jaú
# Processando: Jeriquara
# Processando: Joanópolis
# Processando: João Ramalho
# Processando: José Bonifácio
# Processando: Júlio Mesquita
# Processando: Jumirim
# Processando: Jundiaí
# Processando: Junqueirópolis
# Processando: Juquiá
# Processando: Juquitiba
# Processando: Lagoinha
# Processando: Laranjal Paulista
# Processando: Lavínia
# Processando: Lavrinhas
# Processando: Leme
# Processando: Lençóis Paulista
# Processando: Limeira
# Processando: Lindóia
# Processando: Lins
# Processando: Lorena
# Processando: Lourdes
# Processando: Louveira
# Processando: Lucélia
# Processando: Lucianópolis
# Processando: Luís Antônio
# Processando: Luiziânia
# Processando: Lupércio
# Processando: Lutécia
# Processando: Macatuba
# Processando: Macaubal
# Processando: Macedônia
# Processando: Magda
# Processando: Mairinque
# Processando: Mairiporã
# Processando: Manduri
# Processando: Marabá Paulista
# Processando: Maracaí
# Processando: Marapoama
# Processando: Mariápolis
# Processando: Marília
# Processando: Marinópolis
# Processando: Martinópolis
# Processando: Matão
# Processando: Mauá
# Processando: Mendonça
# Processando: Meridiano
# Processando: Mesópolis
# Processando: Miguelópolis
# Processando: Mineiros do Tietê
# Processando: Miracatu
# Processando: Mira Estrela
# Processando: Mirandópolis
# Processando: Mirante do Paranapanema
# Processando: Mirassol
# Processando: Mirassolândia
# Processando: Mococa
# Processando: Mogi das Cruzes
# Processando: Mogi Guaçu
# Processando: Mogi Mirim
# Processando: Mombuca
# Processando: Monções
# Processando: Mongaguá
# Processando: Monte Alegre do Sul
# Processando: Monte Alto
# Processando: Monte Aprazível
# Processando: Monte Azul Paulista
# Processando: Monte Castelo
# Processando: Monteiro Lobato
# Processando: Monte Mor
# Processando: Morro Agudo
# Processando: Morungaba
# Processando: Motuca
# Processando: Murutinga do Sul
# Processando: Nantes
# Processando: Narandiba
# Processando: Natividade da Serra
# Processando: Nazaré Paulista
# Processando: Neves Paulista
# Processando: Nhandeara
# Processando: Nipoã
# Processando: Nova Aliança
# Processando: Nova Campina
# Processando: Nova Canaã Paulista
# Processando: Nova Castilho
# Processando: Nova Europa
# Processando: Nova Granada
# Processando: Nova Guataporanga
# Processando: Nova Independência
# Processando: Novais
# Processando: Nova Luzitânia
# Processando: Nova Odessa
# Processando: Novo Horizonte
# Processando: Nuporanga
# Processando: Ocauçu
# Processando: Óleo
# Processando: Olímpia
# Processando: Onda Verde
# Processando: Oriente
# Processando: Orindiúva
# Processando: Orlândia
# Processando: Osasco
# Processando: Oscar Bressane
# Processando: Osvaldo Cruz
# Processando: Ourinhos
# Processando: Ouroeste
# Processando: Ouro Verde
# Processando: Pacaembu
# Processando: Palestina
# Processando: Palmares Paulista
# Processando: Palmeira d'Oeste
# Processando: Palmital
# Processando: Panorama
# Processando: Paraguaçu Paulista
# Processando: Paraibuna
# Processando: Paraíso
# Processando: Paranapanema
# Processando: Paranapuã
# Processando: Parapuã
# Processando: Pardinho
# Processando: Pariquera-Açu
# Processando: Parisi
# Processando: Patrocínio Paulista
# Processando: Paulicéia
# Processando: Paulínia
# Processando: Paulistânia
# Processando: Paulo de Faria
# Processando: Pederneiras
# Processando: Pedra Bela
# Processando: Pedranópolis
# Processando: Pedregulho
# Processando: Pedreira
# Processando: Pedrinhas Paulista
# Processando: Pedro de Toledo
# Processando: Penápolis
# Processando: Pereira Barreto
# Processando: Pereiras
# Processando: Peruíbe
# Processando: Piacatu
# Processando: Piedade
# Processando: Pilar do Sul
# Processando: Pindamonhangaba
# Processando: Pindorama
# Processando: Pinhalzinho
# Processando: Piquerobi
# Processando: Piquete
# Processando: Piracaia
# Processando: Piracicaba
# Processando: Piraju
# Processando: Pirajuí
# Processando: Pirangi
# Processando: Pirapora do Bom Jesus
# Processando: Pirapozinho
# Processando: Pirassununga
# Processando: Piratininga
# Processando: Pitangueiras
# Processando: Planalto
# Processando: Platina
# Processando: Poá
# Processando: Poloni
# Processando: Pompéia
# Processando: Pongaí
# Processando: Pontal
# Processando: Pontalinda
# Processando: Pontes Gestal
# Processando: Populina
# Processando: Porangaba
# Processando: Porto Feliz
# Processando: Porto Ferreira
# Processando: Potim
# Processando: Potirendaba
# Processando: Pracinha
# Processando: Pradópolis
# Processando: Praia Grande
# Processando: Pratânia
# Processando: Presidente Alves
# Processando: Presidente Bernardes
# Processando: Presidente Epitácio
# Processando: Presidente Prudente
# Processando: Presidente Venceslau
# Processando: Promissão
# Processando: Quadra
# Processando: Quatá
# Processando: Queiroz
# Processando: Queluz
# Processando: Quintana
# Processando: Rafard
# Processando: Rancharia
# Processando: Redenção da Serra
# Processando: Regente Feijó
# Processando: Reginópolis
# Processando: Registro
# Processando: Restinga
# Processando: Ribeira
# Processando: Ribeirão Bonito
# Processando: Ribeirão Branco
# Processando: Ribeirão Corrente
# Processando: Ribeirão do Sul
# Processando: Ribeirão dos Índios
# Processando: Ribeirão Grande
# Processando: Ribeirão Pires
# Processando: Ribeirão Preto
# Processando: Riversul
# Processando: Rifaina
# Processando: Rincão
# Processando: Rinópolis
# Processando: Rio Claro
# Processando: Rio das Pedras
# Processando: Rio Grande da Serra
# Processando: Riolândia
# Processando: Rosana
# Processando: Roseira
# Processando: Rubiácea
# Processando: Rubinéia
# Processando: Sabino
# Processando: Sagres
# Processando: Sales
# Processando: Sales Oliveira
# Processando: Salesópolis
# Processando: Salmourão
# Processando: Saltinho
# Processando: Salto
# Processando: Salto de Pirapora
# Processando: Salto Grande
# Processando: Sandovalina
# Processando: Santa Adélia
# Processando: Santa Albertina
# Processando: Santa Bárbara d'Oeste
# Processando: Santa Branca
# Processando: Santa Clara d'Oeste
# Processando: Santa Cruz da Conceição
# Processando: Santa Cruz da Esperança
# Processando: Santa Cruz das Palmeiras
# Processando: Santa Cruz do Rio Pardo
# Processando: Santa Ernestina
# Processando: Santa Fé do Sul
# Processando: Santa Gertrudes
# Processando: Santa Isabel
# Processando: Santa Lúcia
# Processando: Santa Maria da Serra
# Processando: Santa Mercedes
# Processando: Santana da Ponte Pensa
# Processando: Santana de Parnaíba
# Processando: Santa Rita d'Oeste
# Processando: Santa Rita do Passa Quatro
# Processando: Santa Rosa de Viterbo
# Processando: Santa Salete
# Processando: Santo Anastácio
# Processando: Santo André
# Processando: Santo Antônio da Alegria
# Processando: Santo Antônio de Posse
# Processando: Santo Antônio do Aracanguá
# Processando: Santo Antônio do Jardim
# Processando: Santo Antônio do Pinhal
# Processando: Santo Expedito
# Processando: Santópolis do Aguapeí
# Processando: Santos
# Processando: São Bento do Sapucaí
# Processando: São Bernardo do Campo
# Processando: São Caetano do Sul
# Processando: São Carlos
# Processando: São Francisco
# Processando: São João da Boa Vista
# Processando: São João das Duas Pontes
# Processando: São João de Iracema
# Processando: São João do Pau d'Alho
# Processando: São Joaquim da Barra
# Processando: São José da Bela Vista
# Processando: São José do Barreiro
# Processando: São José do Rio Pardo
# Processando: São José do Rio Preto
# Processando: São José dos Campos
# Processando: São Lourenço da Serra
# Processando: São Luiz do Paraitinga
# Processando: São Manuel
# Processando: São Miguel Arcanjo
# Processando: São Paulo
# Processando: São Pedro
# Processando: São Pedro do Turvo
# Processando: São Roque
# Processando: São Sebastião
# Processando: São Sebastião da Grama
# Processando: São Simão
# Processando: São Vicente
# Processando: Sarapuí
# Processando: Sarutaiá
# Processando: Sebastianópolis do Sul
# Processando: Serra Azul
# Processando: Serrana
# Processando: Serra Negra
# Processando: Sertãozinho
# Processando: Sete Barras
# Processando: Severínia
# Processando: Silveiras
# Processando: Socorro
# Processando: Sorocaba
# Processando: Sud Mennucci
# Processando: Sumaré
# Processando: Suzano
# Processando: Suzanápolis
# Processando: Tabapuã
# Processando: Tabatinga
# Processando: Taboão da Serra
# Processando: Taciba
# Processando: Taguaí
# Processando: Taiaçu
# Processando: Taiúva
# Processando: Tambaú
# Processando: Tanabi
# Processando: Tapiraí
# Processando: Tapiratiba
# Processando: Taquaral
# Processando: Taquaritinga
# Processando: Taquarituba
# Processando: Taquarivaí
# Processando: Tarabai
# Processando: Tarumã
# Processando: Tatuí
# Processando: Taubaté
# Processando: Tejupá
# Processando: Teodoro Sampaio
# Processando: Terra Roxa
# Processando: Tietê
# Processando: Timburi
# Processando: Torre de Pedra
# Processando: Torrinha
# Processando: Trabiju
# Processando: Tremembé
# Processando: Três Fronteiras
# Processando: Tuiuti
# Processando: Tupã
# Processando: Tupi Paulista
# Processando: Turiúba
# Processando: Turmalina
# Processando: Ubarana
# Processando: Ubatuba
# Processando: Ubirajara
# Processando: Uchoa
# Processando: União Paulista
# Processando: Urânia
# Processando: Uru
# Processando: Urupês
# Processando: Valentim Gentil
# Processando: Valinhos
# Processando: Valparaíso
# Processando: Vargem
# Processando: Vargem Grande do Sul
# Processando: Vargem Grande Paulista
# Processando: Várzea Paulista
# Processando: Vera Cruz
# Processando: Vinhedo
# Processando: Viradouro
# Processando: Vista Alegre do Alto
# Processando: Vitória Brasil
# Processando: Votorantim
# Processando: Votuporanga
# Processando: Zacarias
# Processando: Chavantes
# Processando: Estiva Gerbi
#
# Processo concluído! Resultados salvos em gabriel_top10.json
# Total de municípios com Gabriel no top 10: 109
# Gabriel foi o nome MAIS popular (1º lugar) em 0 municípios.
